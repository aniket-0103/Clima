# %%
import sklearn as sk
import numpy as np
import pandas as pd
import seaborn as sns

# %%
from sklearn.datasets import make_regression
X,y= make_regression(n_samples=200, n_features=1, noise=6,bias=30, random_state=200)
X = np.array(X)
y = np.array(y)
m=200

# %%
from matplotlib import pyplot as plt
plt.scatter(X,y, c="green" ,alpha=.5 ,marker='o')
plt.xlabel("X")
plt.ylabel("Y")
plt.show()

# %%
import numpy as np 
def h(X,w):
    return (w[1]*np.array(X[:,0])+w[0])

# %%
def cost(w,X,y):
    return ((0.5/m)*np.sum(np.square(h(X,w)-np.array(y))))

# %%
def grad(w,X,y):
    g=[0]*2
    g[0]=(1/m)*np.sum(h(X,w)-np.array(y))
    g[1]=(1/m)*np.sum(h(X,w)-np.array(y))*np.array(X[:,0])
    return g

# %%
def descent(w_new,w_prev,lr):
    print(w_prev)
    print(cost(w_prev,X,y))
    j=0
    while True:
        w_prev=w_new
        w0=w_prev[0] - lr*grad(w_prev,X,y)[0]
        w1=w_prev[1] - lr*grad(w_prev,X,y)[1]
        w_new=[w0,w1]
        print(w_new)
        print(cost(w_new,X,y))
        if(w_new[0]-w_prev[0])**2+ (w_new[0]-w_prev[0])**2 <= pow(10,-6):
            return w_new
        if j>500:
            return w_new
        j+=1

# %%
w = [0,-1]
w = descent(w,w,-1)
print(w)
# Out:
# -1
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-27-03956ff8efd7> in <module>
#       1 w = [0,-1]
# ----> 2 w = descent(w[0],w[1],-1)
#       3 print(w)
#
# <ipython-input-7-552320253271> in descent(w_new, w_prev, lr)
#       1 def descent(w_new,w_prev,lr):
#       2     print(w_prev)
# ----> 3     print(cost(w_prev,X,y))
#       4     j=0
#       5     while True:
#
# <ipython-input-5-57d94e891507> in cost(w, X, y)
#       1 def cost(w,X,y):
# ----> 2     return ((0.5/m)*np.sum(np.square(h(X,w)-np.array(y))))
#
# <ipython-input-4-65f7a98ad465> in h(X, w)
#       1 import numpy as np
#       2 def h(X,w):
# ----> 3     return (w[1]*np.array(X[:,0])+w[0])
#
# TypeError: 'int' object is not subscriptable

# %%
def graph(formula,x_range):
    a=np.array(x_range)
    b=np.array(formula)
    plt.plot(a,b)

def my_formula(X):
    return w[0]+w[1]*X

# %%
plt.scatter(X, y,c="red" ,alpha=.5,marker ='o')
c=my_formula(X) 
plt.plot(X, c)
plt.xlabel('X')
plt.ylabel('Y')
plt.show()
